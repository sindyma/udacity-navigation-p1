# %% [markdown]
# # Navigation - Report
#
# ---
#
# This notebook contains my report for the first project of the [Deep Reinforcement Learning Nanodegree] for student Sindy Ma (sindyma90@gmail.com)
#
# Github repo: [https://github.com/sindyma/udacity-navigation-p1]

# %% [markdown]
# # Report

# %% [markdown]
# ## Introduction
# In the first project of the Udacity Deep Reinforcement Learning Nanodegree, we are tasked to solve a variation of Unity's Banana environment. In this environment, the agent has a first person view of a walled area. Yellow and purple bananas are falling from the sky. The agent picks up a banana by walking into it.

# %%
from IPython.display import Image, display
display(Image(filename='banana_env.png', width=500))
print("Fig 1. Screenshot of the training environment")
# Out:
# Fig 1. Screenshot of the training environment

# %% [markdown]
# The observation vector is of size 37 and describes the ray-based perception of objects (walls, ground, yellow banana, purple banana) and agent's velocity and agent's forward direction. The number of actions is 4 (move forward, move backward, turn left, turn right). Each time the agent collects a yellow banana, it gets a reward of `+1` and each time it collects a purple banana, it gets a reward of `-1`.
#
# The environment is considered solved when we achieve a score over `13.0` in 100 time steps. In the implementation I describe in this report, this took `<x>` episodes and the average score was `<x>`.

# %% [markdown]
# ## Learning algorithm: DQN

# %% [markdown]
# **Learning Algorithm**
# * Description of DQN
#     * What is DQN
#     * Reward function
#     * Quick description of architecture > agent code, model code, notebook
# * This implementation
#     * Hyper parameter choice
#     * Comparison of a few different runs
#     * Neural network architecture
#     * Comparison of different architectures

# %% [markdown]
# ## Results

# %% [markdown]
# **Plot of rewards**
# * Plot
# * Description of what is in the plot
# * Episodes used to solve

# %% [markdown]
# ## Ideas for improvement

# %% [markdown]
# **Ideas for future work**
# * Prioritized replay
# * Double DQN
# * Epsilon Decay change
